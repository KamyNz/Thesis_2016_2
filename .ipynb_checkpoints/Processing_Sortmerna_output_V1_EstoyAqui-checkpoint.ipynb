# %%
# Importing all the neede 
import os
import itertools
import numpy as np

#from Bio.Blast import NCBIXML

# Biopython is required for reading multifasta files and storing sequences.
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio.Alphabet import IUPAC

from Utils import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-48-47039e2bf4c1> in <module>()
#      11 from Bio.Alphabet import IUPAC
#      12
# ---> 13 from Utils import *
#
# ImportError: No module named Utils

# %% [markdown]
# # Poner condiciones sobre el tamano de la subunidad

# %%
subunit_16s = 1542
subunit_23s = 2905
subunit_5s = 120

# %%
# Other things
mainPath = "/Users/CamilaMV/Desktop/sortmernaFiles/Genos_4000_400/"
mainPath2 = "/Users/CamilaMV/Desktop/sortmernaFiles/Genos_4000_400/FastaFiles/"

# %%
#mainPath = "/Users/CamilaMV/Desktop/sortmernaFiles/Genos_3000_300/"
#mainPath2 = "/Users/CamilaMV/Desktop/sortmernaFiles/Genos_3000_300/FastaFiles/"

# %%
def parse_tabular_blast_results(blast_results_file):
    """
    Parse out the BLAST results from a tabular format BLAST results file into a 
    2D dictionary containing query id/name -> subject id/name -> BLAST result.
    Args:
        blast_results_file (string): Path to tabular BLAST results file.
    Returns:
        2D dictionary containing query id/name -> subject id/name -> BLAST result
    """
    # results are stored in a 2D dictionary - query -> subject -> BLAST result
    results = {}
    with open(blast_results_file,'r') as f:
        for line in f:
            line = line.rstrip()
            sp = line.split('\t')
            # get query id
            q = sp[0]
            q_len = query_lengths[q]
            # get subject id
            s = sp[1]
            # get % identity and convert to decimal (e.g. 96.7 -> 0.967)
            pid1 = float(sp[2])
            pid2 = float(sp[2])/100.0
            # get alignment length
            aln_len = int(sp[3])
            # get query start index
            q_s_i = int(sp[6])
            # get query end index
            q_e_i = int(sp[7])
            # get subject start index
            s_s_i = int(sp[8])
            # get subject end index
            s_e_i = int(sp[9])
            
            q_cov = sp[12]
            
            # number of identities (count of positive sequence matches)
            identities = int(aln_len*pid2)
            
            # the results for a particular query could be whatever you need
            # in this example, a dictionary is made where different results have
            # different identifiers for instance
            result_dict = {'aln_len':aln_len, 
            'q_len':q_len,
            'pid':pid1,
            'identities':identities,
            'q_s_i':q_s_i, 
            'q_e_i':q_e_i,
            's_s_i':s_s_i,
            's_e_i':s_e_i,
            'qcov':q_cov
            }
            
            # could add more items to this BLAST result dictionary
            if q not in results:
                results[q] = {s:[result_dict]}
            else:
                if s not in results[q]:
                    results[q][s] = [result_dict]
                else:
                    results[q][s].append(result_dict)
            
    return results

# %% [markdown]
# # Reading blast files for 16s, 23s and 5s for all genos

# %%
# getting blast genos
folder1 = mainPath +"Results16s/"
#genosNames = Processing_files_from_folder(folder1,10)

# %%
print os.path.isdir(mainPath)
# Out:
# True

# %%
print mainPath, mainPath2
# Out:
# /Users/CamilaMV/Desktop/sortmernaFiles/Genos_4000_400/ /Users/CamilaMV/Desktop/sortmernaFiles/Genos_4000_400/FastaFiles/

# %%
genosNamesFasta,genosNamesFastaExists = Processing_files_from_folder(mainPath2)

# %%
#genosNamesFinalBlast = Getting_files_path_by_extension(genosNames,".blast")[0]

# %%
#genosNamesFinalNames = Getting_files_path_by_extension(genosNamesFinal,".split")[0]
nameGenos = []
for genoName in genosNamesFasta:
    
    nameGenos.append(genoName.split(".split")[0])

# %%
print genosNamesFasta

print ()

print nameGenos
# Out:
# ['2362_nt.split.4Kmer.400overlap.fasta.fastaN', 'B1-CDA_nt.split.4Kmer.400overlap.fasta.fastaN', 'C3-41_nt.split.4Kmer.400overlap.fasta.fastaN', 'CBAM5_nt.split.4Kmer.400overlap.fasta.fastaN', 'III37_nt.split.4Kmer.400overlap.fasta.fastaN', 'Ot4b.25_nt.split.4Kmer.400overlap.fasta.fastaN', 'Ot4b.31_nt.split.4Kmer.400overlap.fasta.fastaN', 'Ot4b.49_nt.split.4Kmer.400overlap.fasta.fastaN', 'RB-21.split.4Kmer.400overlap.fasta.fastaN', 'Silvestris.split.4Kmer.400overlap.fasta.fastaN']
# ()
# ['2362_nt', 'B1-CDA_nt', 'C3-41_nt', 'CBAM5_nt', 'III37_nt', 'Ot4b.25_nt', 'Ot4b.31_nt', 'Ot4b.49_nt', 'RB-21', 'Silvestris']

# %%
folder16s = mainPath+"Results16s/"
folder23s = mainPath+"Results23s/"
folder5s = mainPath+"Results5s/"

# %%
print folder16s
print folder23s
print folder5s
# Out:
# /Users/CamilaMV/Desktop/sortmernaFiles/Genos_4000_400/Results16s/
# /Users/CamilaMV/Desktop/sortmernaFiles/Genos_4000_400/Results23s/
# /Users/CamilaMV/Desktop/sortmernaFiles/Genos_4000_400/Results5s/

# %% [markdown]
# # Processing blast results of 16s, 23s and 5s for all genos

# %%
os.getcwd()
# Out:
# '/Users/CamilaMV/Desktop/TESIS/Python_Notebooks/Tesis_2016_2'

# %%
os.chdir('/Users/CamilaMV/Desktop/')

# %%
os.getcwd()
# Out:
# '/Users/CamilaMV/Desktop'

# %% [markdown]
# # Getting the Operons subunits for each geno

# %%
#path16s, path23s and path5s are constant
genos_results_subunits_dict = {}

# Processing tabular results
for genoFasta, gname in itertools.izip(genosNamesFasta,nameGenos):
    
    # Query lengths temporal
    pathTemp = mainPath2 + genoFasta
    query_files = [pathTemp]
    query_lengths = {rec.name:len(rec.seq) for q_file in query_files for rec in SeqIO.parse(q_file, 'fasta')}
        
    # Processing blast results
    p16s = folder16s+genoFasta+".16s.blast"
    p23s = folder23s+genoFasta+".23s.blast"
    p5s = folder5s+genoFasta+".5s.blast"
        
    # Using function parse_tabular_blast_results, NOT MINE
    results_geno_temp_16s = parse_tabular_blast_results(p16s)
    results_geno_temp_23s = parse_tabular_blast_results(p23s)
    results_geno_temp_5s = parse_tabular_blast_results(p5s)
    
    # Making intersection for each geno
    intersection_16_23s_geno_temp = set(results_geno_temp_16s.keys()).intersection(results_geno_temp_23s.keys())
    intersection_16_23_5s_geno_temp = intersection_16_23s_geno_temp.intersection(results_geno_temp_5s.keys())
    
    # Putting results for each geno as value of dictionary
    dict_frag_subunits = {}
    for keyFrag in intersection_16_23_5s_geno_temp:
        
        listTemp = [results_geno_temp_16s[keyFrag],results_geno_temp_23s[keyFrag],results_geno_temp_5s[keyFrag]]
        
        dict_frag_subunits[keyFrag] = listTemp
        
    # Putting final results in big dictionary
    genos_results_subunits_dict[gname] = dict_frag_subunits

# %%
genos_results_subunits_dict.keys()
# Out:
# ['CBAM5_nt',
#  '2362_nt',
#  'C3-41_nt',
#  'Ot4b.25_nt',
#  'Silvestris',
#  'B1-CDA_nt',
#  'Ot4b.31_nt',
#  'RB-21',
#  'Ot4b.49_nt',
#  'III37_nt']

# %% [markdown]
# # Looking the results

# %%
genos_results_subunits_dict
# Out:
# {'2362_nt': {'Frag_1070': [{'LsnSph30': [{'aln_len': 1363,
#       'identities': 1339,
#       'pid': 98.3,
#       'q_e_i': 3477,
#       'q_len': 4000,
#       'q_s_i': 2115,
#       'qcov': '34.1',
#       's_e_i': 1353,
#       's_s_i': 1}]},
#    {'CloTet37': [{'aln_len': 78,
#       'identities': 75,
#       'pid': 97.4,
#       'q_e_i': 3699,
#       'q_len': 4000,
#       'q_s_i': 3622,
#       'qcov': '1.95',
#       's_e_i': 282,
#       's_s_i': 205}]},
#    {'AAKN02015069.1/34289-34169': [{'aln_len': 44,
#       'identities': 37,
#       'pid': 84.1,
#       'q_e_i': 3753,
#       'q_len': 4000,
#       'q_s_i': 3710,
#       'qcov': '1.1',
#       's_e_i': 109,
#       's_s_i': 66}]}],
#   'Frag_1071': [{'LetYel14': [{'aln_len': 78,
#       'identities': 73,
#       'pid': 93.6,
#       'q_e_i': 98,
#       'q_len': 4000,
#       'q_s_i': 21,
#       'qcov': '1.95',
#       's_e_i': 1648,
#       's_s_i': 1571}]},
#    {'Bac12248': [{'aln_len': 2931,
#       'identities': 2931,
#       'pid': 100.0,
#       'q_e_i': 3329,
#       'q_len': 4000,
#       'q_s_i': 399,
#       'qcov': '73.3',
#       's_e_i': 2931,
#       's_s_i': 1}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 3626,
#       'q_len': 4000,
#       'q_s_i': 3511,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_1099': [{'LsnSph30': [{'aln_len': 1363,
#       'identities': 1342,
#       'pid': 98.5,
#       'q_e_i': 3880,
#       'q_len': 4000,
#       'q_s_i': 2518,
#       'qcov': '34.1',
#       's_e_i': 1353,
#       's_s_i': 1}]},
#    {'Bac12248': [{'aln_len': 1169,
#       'identities': 1169,
#       'pid': 100.0,
#       'q_e_i': 1169,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '29.2',
#       's_e_i': 2923,
#       's_s_i': 1755}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 1408,
#       'q_len': 4000,
#       'q_s_i': 1293,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_1100': [{'Unc10009': [{'aln_len': 290,
#       'identities': 289,
#       'pid': 99.7,
#       'q_e_i': 290,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '7.25',
#       's_e_i': 1556,
#       's_s_i': 1268}]},
#    {'Bac12248': [{'aln_len': 2931,
#       'identities': 2931,
#       'pid': 100.0,
#       'q_e_i': 3733,
#       'q_len': 4000,
#       'q_s_i': 803,
#       'qcov': '73.3',
#       's_e_i': 2931,
#       's_s_i': 1}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 80,
#       'identities': 80,
#       'pid': 100.0,
#       'q_e_i': 4000,
#       'q_len': 4000,
#       'q_s_i': 3921,
#       'qcov': '2',
#       's_e_i': 83,
#       's_s_i': 4}]}],
#   'Frag_1132': [{'NosSpe42': [{'aln_len': 83,
#       'identities': 67,
#       'pid': 81.0,
#       'q_e_i': 2940,
#       'q_len': 4000,
#       'q_s_i': 2858,
#       'qcov': '2.08',
#       's_e_i': 1673,
#       's_s_i': 1591}]},
#    {'Bac12248': [{'aln_len': 2668,
#       'identities': 2668,
#       'pid': 100.0,
#       'q_e_i': 2668,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '66.7',
#       's_e_i': 2923,
#       's_s_i': 256}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 116,
#       'identities': 116,
#       'pid': 100.0,
#       'q_e_i': 2855,
#       'q_len': 4000,
#       'q_s_i': 2740,
#       'qcov': '2.9',
#       's_e_i': 116,
#       's_s_i': 1}]}],
#   'Frag_785': [{'NosSpe42': [{'aln_len': 84,
#       'identities': 70,
#       'pid': 84.5,
#       'q_e_i': 1646,
#       'q_len': 4000,
#       'q_s_i': 1563,
#       'qcov': '2.1',
#       's_e_i': 1680,
#       's_s_i': 1599}]},
#    {'CloTet37': [{'aln_len': 158,
#       'identities': 123,
#       'pid': 78.4,
#       'q_e_i': 2426,
#       'q_len': 4000,
#       'q_s_i': 2269,
#       'qcov': '3.95',
#       's_e_i': 281,
#       's_s_i': 113}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 817,
#       'q_len': 4000,
#       'q_s_i': 702,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_787': [{'LetYel14': [{'aln_len': 76,
#       'identities': 70,
#       'pid': 93.4,
#       'q_e_i': 2101,
#       'q_len': 4000,
#       'q_s_i': 2026,
#       'qcov': '1.9',
#       's_e_i': 1645,
#       's_s_i': 1570}]},
#    {'Bac12248': [{'aln_len': 187,
#       'identities': 187,
#       'pid': 100.0,
#       'q_e_i': 187,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '4.67',
#       's_e_i': 2923,
#       's_s_i': 2737}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 495,
#       'q_len': 4000,
#       'q_s_i': 380,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_867': [{'NosSpe42': [{'aln_len': 75,
#       'identities': 59,
#       'pid': 78.9,
#       'q_e_i': 1930,
#       'q_len': 4000,
#       'q_s_i': 1856,
#       'qcov': '1.88',
#       's_e_i': 1673,
#       's_s_i': 1599}]},
#    {'Bac12248': [{'aln_len': 1314,
#       'identities': 1314,
#       'pid': 100.0,
#       'q_e_i': 1314,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '32.9',
#       's_e_i': 2923,
#       's_s_i': 1610}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 1548,
#       'q_len': 4000,
#       'q_s_i': 1433,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}]},
#  'B1-CDA_nt': {'Frag_1': [{'NosSpe42': [{'aln_len': 83,
#       'identities': 66,
#       'pid': 79.8,
#       'q_e_i': 2990,
#       'q_len': 4000,
#       'q_s_i': 2908,
#       'qcov': '2.08',
#       's_e_i': 1673,
#       's_s_i': 1591}]},
#    {'AgrSp219': [{'aln_len': 84,
#       'identities': 74,
#       'pid': 88.1,
#       'q_e_i': 3904,
#       'q_len': 4000,
#       'q_s_i': 3821,
#       'qcov': '2.1',
#       's_e_i': 88,
#       's_s_i': 5}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 95,
#       'identities': 95,
#       'pid': 100.0,
#       'q_e_i': 2905,
#       'q_len': 4000,
#       'q_s_i': 2811,
#       'qcov': '2.38',
#       's_e_i': 116,
#       's_s_i': 22}]}],
#   'Frag_145': [{'RvlSpec9': [{'aln_len': 68,
#       'identities': 54,
#       'pid': 79.7,
#       'q_e_i': 1752,
#       'q_len': 4000,
#       'q_s_i': 1685,
#       'qcov': '1.7',
#       's_e_i': 1690,
#       's_s_i': 1623}]},
#    {'UncRo447': [{'aln_len': 78,
#       'identities': 64,
#       'pid': 82.1,
#       'q_e_i': 1753,
#       'q_len': 4000,
#       'q_s_i': 1676,
#       'qcov': '1.95',
#       's_e_i': 78,
#       's_s_i': 1}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 87,
#       'identities': 87,
#       'pid': 100.0,
#       'q_e_i': 1369,
#       'q_len': 4000,
#       'q_s_i': 1283,
#       'qcov': '2.17',
#       's_e_i': 112,
#       's_s_i': 26}]}]},
#  'C3-41_nt': {'Frag_101': [{'NosSpe42': [{'aln_len': 75,
#       'identities': 59,
#       'pid': 78.9,
#       'q_e_i': 3153,
#       'q_len': 4000,
#       'q_s_i': 3079,
#       'qcov': '1.88',
#       's_e_i': 1673,
#       's_s_i': 1599}]},
#    {'Bac12248': [{'aln_len': 2533,
#       'identities': 2520,
#       'pid': 99.5,
#       'q_e_i': 2533,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '63.3',
#       's_e_i': 2919,
#       's_s_i': 391}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 2771,
#       'q_len': 4000,
#       'q_s_i': 2656,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_1158': [{'LetYel14': [{'aln_len': 79,
#       'identities': 74,
#       'pid': 93.7,
#       'q_e_i': 3363,
#       'q_len': 4000,
#       'q_s_i': 3285,
#       'qcov': '1.98',
#       's_e_i': 1648,
#       's_s_i': 1570}]},
#    {'CloTet37': [{'aln_len': 158,
#       'identities': 123,
#       'pid': 78.4,
#       'q_e_i': 3363,
#       'q_len': 4000,
#       'q_s_i': 3206,
#       'qcov': '3.95',
#       's_e_i': 281,
#       's_s_i': 113}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 1754,
#       'q_len': 4000,
#       'q_s_i': 1639,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_1231': [{'LsnCreso': [{'aln_len': 362,
#       'identities': 362,
#       'pid': 100.0,
#       'q_e_i': 362,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '9.05',
#       's_e_i': 1444,
#       's_s_i': 1083}]},
#    {'Bac12248': [{'aln_len': 2931,
#       'identities': 2925,
#       'pid': 99.8,
#       'q_e_i': 3656,
#       'q_len': 4000,
#       'q_s_i': 726,
#       'qcov': '73.3',
#       's_e_i': 2930,
#       's_s_i': 1}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 113,
#       'pid': 97.5,
#       'q_e_i': 3957,
#       'q_len': 4000,
#       'q_s_i': 3842,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_15': [{'Unc10009': [{'aln_len': 346,
#       'identities': 342,
#       'pid': 99.1,
#       'q_e_i': 346,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '8.65',
#       's_e_i': 1555,
#       's_s_i': 1213}]},
#    {'Bac12248': [{'aln_len': 2931,
#       'identities': 2928,
#       'pid': 99.9,
#       'q_e_i': 3789,
#       'q_len': 4000,
#       'q_s_i': 859,
#       'qcov': '73.3',
#       's_e_i': 2931,
#       's_s_i': 1}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 27,
#       'identities': 27,
#       'pid': 100.0,
#       'q_e_i': 4000,
#       'q_len': 4000,
#       'q_s_i': 3974,
#       'qcov': '0.675',
#       's_e_i': 27,
#       's_s_i': 1}]}],
#   'Frag_212': [{'LsnCreso': [{'aln_len': 605,
#       'identities': 603,
#       'pid': 99.8,
#       'q_e_i': 605,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '15.1',
#       's_e_i': 1444,
#       's_s_i': 840}]},
#    {'Bac12248': [{'aln_len': 2929,
#       'identities': 2926,
#       'pid': 99.9,
#       'q_e_i': 3896,
#       'q_len': 4000,
#       'q_s_i': 968,
#       'qcov': '73.2',
#       's_e_i': 2931,
#       's_s_i': 1}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 41,
#       'identities': 41,
#       'pid': 100.0,
#       'q_e_i': 4000,
#       'q_len': 4000,
#       'q_s_i': 3960,
#       'qcov': '1.03',
#       's_e_i': 41,
#       's_s_i': 1}]}],
#   'Frag_213': [{'LetYel14': [{'aln_len': 77,
#       'identities': 70,
#       'pid': 92.2,
#       'q_e_i': 1805,
#       'q_len': 4000,
#       'q_s_i': 1729,
#       'qcov': '1.93',
#       's_e_i': 1648,
#       's_s_i': 1572}]},
#    {'Bac12248': [{'aln_len': 288,
#       'identities': 288,
#       'pid': 100.0,
#       'q_e_i': 288,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '7.2',
#       's_e_i': 2923,
#       's_s_i': 2636}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 116,
#       'identities': 116,
#       'pid': 100.0,
#       'q_e_i': 475,
#       'q_len': 4000,
#       'q_s_i': 360,
#       'qcov': '2.9',
#       's_e_i': 116,
#       's_s_i': 1}]}],
#   'Frag_31': [{'LsnSph30': [{'aln_len': 1362,
#       'identities': 1340,
#       'pid': 98.4,
#       'q_e_i': 2733,
#       'q_len': 4000,
#       'q_s_i': 1372,
#       'qcov': '34.1',
#       's_e_i': 1353,
#       's_s_i': 1}]},
#    {'Bac12248': [{'aln_len': 746,
#       'identities': 745,
#       'pid': 99.9,
#       'q_e_i': 4000,
#       'q_len': 4000,
#       'q_s_i': 3255,
#       'qcov': '18.6',
#       's_e_i': 746,
#       's_s_i': 1}]},
#    {'AAKN02015069.1/34289-34169': [{'aln_len': 44,
#       'identities': 37,
#       'pid': 84.1,
#       'q_e_i': 3009,
#       'q_len': 4000,
#       'q_s_i': 2966,
#       'qcov': '1.1',
#       's_e_i': 109,
#       's_s_i': 66}]}],
#   'Frag_5': [{'LsnSph30': [{'aln_len': 1363,
#       'identities': 1342,
#       'pid': 98.5,
#       'q_e_i': 3911,
#       'q_len': 4000,
#       'q_s_i': 2549,
#       'qcov': '34.1',
#       's_e_i': 1353,
#       's_s_i': 1}]},
#    {'Bac12248': [{'aln_len': 640,
#       'identities': 640,
#       'pid': 100.0,
#       'q_e_i': 640,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '16',
#       's_e_i': 2923,
#       's_s_i': 2284}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 945,
#       'q_len': 4000,
#       'q_s_i': 830,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_6': [{'Unc10009': [{'aln_len': 320,
#       'identities': 318,
#       'pid': 99.4,
#       'q_e_i': 320,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '8',
#       's_e_i': 1555,
#       's_s_i': 1238}]},
#    {'Bac12248': [{'aln_len': 2931,
#       'identities': 2925,
#       'pid': 99.8,
#       'q_e_i': 3764,
#       'q_len': 4000,
#       'q_s_i': 834,
#       'qcov': '73.3',
#       's_e_i': 2930,
#       's_s_i': 1}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 51,
#       'identities': 51,
#       'pid': 100.0,
#       'q_e_i': 4000,
#       'q_len': 4000,
#       'q_s_i': 3950,
#       'qcov': '1.27',
#       's_e_i': 51,
#       's_s_i': 1}]}]},
#  'CBAM5_nt': {'Frag_1166': [{'LetYel14': [{'aln_len': 77,
#       'identities': 70,
#       'pid': 92.2,
#       'q_e_i': 3257,
#       'q_len': 4000,
#       'q_s_i': 3181,
#       'qcov': '1.93',
#       's_e_i': 1648,
#       's_s_i': 1572}]},
#    {'CloTet37': [{'aln_len': 162,
#       'identities': 127,
#       'pid': 78.7,
#       'q_e_i': 3258,
#       'q_len': 4000,
#       'q_s_i': 3097,
#       'qcov': '4.05',
#       's_e_i': 282,
#       's_s_i': 111}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 62,
#       'identities': 62,
#       'pid': 100.0,
#       'q_e_i': 2033,
#       'q_len': 4000,
#       'q_s_i': 1972,
#       'qcov': '1.55',
#       's_e_i': 62,
#       's_s_i': 1}]}],
#   'Frag_1295': [{'NosSpe42': [{'aln_len': 84,
#       'identities': 70,
#       'pid': 84.5,
#       'q_e_i': 1018,
#       'q_len': 4000,
#       'q_s_i': 935,
#       'qcov': '2.1',
#       's_e_i': 1680,
#       's_s_i': 1599}]},
#    {'PseA1731': [{'aln_len': 100,
#       'identities': 85,
#       'pid': 85.0,
#       'q_e_i': 1036,
#       'q_len': 4000,
#       'q_s_i': 937,
#       'qcov': '2.5',
#       's_e_i': 99,
#       's_s_i': 2}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 188,
#       'q_len': 4000,
#       'q_s_i': 73,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_1465': [{'NosSpe42': [{'aln_len': 74,
#       'identities': 58,
#       'pid': 78.7,
#       'q_e_i': 670,
#       'q_len': 4000,
#       'q_s_i': 597,
#       'qcov': '1.85',
#       's_e_i': 1673,
#       's_s_i': 1600}]},
#    {'PdbSp172': [{'aln_len': 70,
#       'identities': 62,
#       'pid': 88.7,
#       'q_e_i': 1332,
#       'q_len': 4000,
#       'q_s_i': 1263,
#       'qcov': '1.75',
#       's_e_i': 71,
#       's_s_i': 1}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 586,
#       'q_len': 4000,
#       'q_s_i': 471,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_1467': [{'LetYel14': [{'aln_len': 82,
#       'identities': 66,
#       'pid': 81.7,
#       'q_e_i': 1271,
#       'q_len': 4000,
#       'q_s_i': 1190,
#       'qcov': '2.05',
#       's_e_i': 1648,
#       's_s_i': 1567}]},
#    {'CloTet37': [{'aln_len': 155,
#       'identities': 121,
#       'pid': 78.6,
#       'q_e_i': 1870,
#       'q_len': 4000,
#       'q_s_i': 1716,
#       'qcov': '3.88',
#       's_e_i': 278,
#       's_s_i': 113}]},
#    {'AAKN02015069.1/34289-34169': [{'aln_len': 44,
#       'identities': 37,
#       'pid': 84.1,
#       'q_e_i': 1053,
#       'q_len': 4000,
#       'q_s_i': 1010,
#       'qcov': '1.1',
#       's_e_i': 109,
#       's_s_i': 66}]}],
#   'Frag_1480': [{'LsnSph30': [{'aln_len': 165,
#       'identities': 164,
#       'pid': 99.4,
#       'q_e_i': 3069,
#       'q_len': 4000,
#       'q_s_i': 2905,
#       'qcov': '4.12',
#       's_e_i': 165,
#       's_s_i': 1}]},
#    {'Bac12248': [{'aln_len': 1115,
#       'identities': 1115,
#       'pid': 100.0,
#       'q_e_i': 1115,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '27.9',
#       's_e_i': 2923,
#       's_s_i': 1809}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 1420,
#       'q_len': 4000,
#       'q_s_i': 1305,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}]},
#  'III37_nt': {'Frag_1216': [{'LetYel14': [{'aln_len': 79,
#       'identities': 74,
#       'pid': 93.7,
#       'q_e_i': 2572,
#       'q_len': 4000,
#       'q_s_i': 2494,
#       'qcov': '1.98',
#       's_e_i': 1648,
#       's_s_i': 1570}]},
#    {'CloTet37': [{'aln_len': 158,
#       'identities': 123,
#       'pid': 78.4,
#       'q_e_i': 2572,
#       'q_len': 4000,
#       'q_s_i': 2415,
#       'qcov': '3.95',
#       's_e_i': 281,
#       's_s_i': 113}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 963,
#       'q_len': 4000,
#       'q_s_i': 848,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_1218': [{'LetYel14': [{'aln_len': 82,
#       'identities': 66,
#       'pid': 81.7,
#       'q_e_i': 1648,
#       'q_len': 4000,
#       'q_s_i': 1567,
#       'qcov': '2.05',
#       's_e_i': 1648,
#       's_s_i': 1567}]},
#    {'Bac12248': [{'aln_len': 333,
#       'identities': 333,
#       'pid': 100.0,
#       'q_e_i': 333,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '8.33',
#       's_e_i': 2923,
#       's_s_i': 2591}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 641,
#       'q_len': 4000,
#       'q_s_i': 526,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_210': [{'Unc00n3n': [{'aln_len': 993,
#       'identities': 947,
#       'pid': 95.4,
#       'q_e_i': 3996,
#       'q_len': 4000,
#       'q_s_i': 3004,
#       'qcov': '24.8',
#       's_e_i': 995,
#       's_s_i': 1}]},
#    {'Bac12248': [{'aln_len': 1226,
#       'identities': 1226,
#       'pid': 100.0,
#       'q_e_i': 1226,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '30.6',
#       's_e_i': 2923,
#       's_s_i': 1698}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 1531,
#       'q_len': 4000,
#       'q_s_i': 1416,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_237': [{'UncSta53': [{'aln_len': 108,
#       'identities': 105,
#       'pid': 98.1,
#       'q_e_i': 4000,
#       'q_len': 4000,
#       'q_s_i': 3893,
#       'qcov': '2.7',
#       's_e_i': 108,
#       's_s_i': 1}]},
#    {'Bac12248': [{'aln_len': 2674,
#       'identities': 2674,
#       'pid': 100.0,
#       'q_e_i': 2674,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '66.8',
#       's_e_i': 2923,
#       's_s_i': 250}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 2913,
#       'q_len': 4000,
#       'q_s_i': 2798,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_238': [{'LsnSph30': [{'aln_len': 1363,
#       'identities': 1342,
#       'pid': 98.5,
#       'q_e_i': 1785,
#       'q_len': 4000,
#       'q_s_i': 423,
#       'qcov': '34.1',
#       's_e_i': 1353,
#       's_s_i': 1}]},
#    {'Bac12248': [{'aln_len': 1693,
#       'identities': 1691,
#       'pid': 99.9,
#       'q_e_i': 4000,
#       'q_len': 4000,
#       'q_s_i': 2308,
#       'qcov': '42.3',
#       's_e_i': 1693,
#       's_s_i': 1}]},
#    {'AAKN02015069.1/34289-34169': [{'aln_len': 44,
#       'identities': 37,
#       'pid': 84.1,
#       'q_e_i': 101,
#       'q_len': 4000,
#       'q_s_i': 58,
#       'qcov': '1.1',
#       's_e_i': 109,
#       's_s_i': 66}]}],
#   'Frag_271': [{'LetYel14': [{'aln_len': 77,
#       'identities': 70,
#       'pid': 92.2,
#       'q_e_i': 2090,
#       'q_len': 4000,
#       'q_s_i': 2014,
#       'qcov': '1.93',
#       's_e_i': 1648,
#       's_s_i': 1572}]},
#    {'Bac12248': [{'aln_len': 573,
#       'identities': 573,
#       'pid': 100.0,
#       'q_e_i': 573,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '14.3',
#       's_e_i': 2923,
#       's_s_i': 2351}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 116,
#       'identities': 116,
#       'pid': 100.0,
#       'q_e_i': 760,
#       'q_len': 4000,
#       'q_s_i': 645,
#       'qcov': '2.9',
#       's_e_i': 116,
#       's_s_i': 1}]}],
#   'Frag_5': [{'RvlSpec9': [{'aln_len': 56,
#       'identities': 46,
#       'pid': 83.1,
#       'q_e_i': 122,
#       'q_len': 4000,
#       'q_s_i': 67,
#       'qcov': '1.4',
#       's_e_i': 1677,
#       's_s_i': 1623}]},
#    {'CanPhot8': [{'aln_len': 79,
#       'identities': 63,
#       'pid': 80.5,
#       'q_e_i': 434,
#       'q_len': 4000,
#       'q_s_i': 356,
#       'qcov': '1.98',
#       's_e_i': 82,
#       's_s_i': 2}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 36,
#       'identities': 36,
#       'pid': 100.0,
#       'q_e_i': 36,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '0.9',
#       's_e_i': 110,
#       's_s_i': 75}]}],
#   'Frag_6': [{'Unc036po': [{'aln_len': 143,
#       'identities': 143,
#       'pid': 100.0,
#       'q_e_i': 143,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '3.57',
#       's_e_i': 1477,
#       's_s_i': 1335}]},
#    {'Bac12248': [{'aln_len': 2931,
#       'identities': 2928,
#       'pid': 99.9,
#       'q_e_i': 3417,
#       'q_len': 4000,
#       'q_s_i': 487,
#       'qcov': '73.3',
#       's_e_i': 2931,
#       's_s_i': 1}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 3643,
#       'q_len': 4000,
#       'q_s_i': 3528,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_75': [{'Unc036po': [{'aln_len': 194,
#       'identities': 194,
#       'pid': 100.0,
#       'q_e_i': 194,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '4.85',
#       's_e_i': 1477,
#       's_s_i': 1284}]},
#    {'Bac12248': [{'aln_len': 2931,
#       'identities': 2931,
#       'pid': 100.0,
#       'q_e_i': 3467,
#       'q_len': 4000,
#       'q_s_i': 537,
#       'qcov': '73.3',
#       's_e_i': 2931,
#       's_s_i': 1}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 3767,
#       'q_len': 4000,
#       'q_s_i': 3652,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}]},
#  'Ot4b.25_nt': {'Frag_118': [{'LetYel14': [{'aln_len': 77,
#       'identities': 70,
#       'pid': 92.2,
#       'q_e_i': 3407,
#       'q_len': 4000,
#       'q_s_i': 3331,
#       'qcov': '1.93',
#       's_e_i': 1648,
#       's_s_i': 1572}]},
#    {'Bac12248': [{'aln_len': 1890,
#       'identities': 1890,
#       'pid': 100.0,
#       'q_e_i': 1890,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '47.2',
#       's_e_i': 2923,
#       's_s_i': 1034}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 116,
#       'identities': 116,
#       'pid': 100.0,
#       'q_e_i': 2077,
#       'q_len': 4000,
#       'q_s_i': 1962,
#       'qcov': '2.9',
#       's_e_i': 116,
#       's_s_i': 1}]}],
#   'Frag_151': [{'LsnSph30': [{'aln_len': 1363,
#       'identities': 1342,
#       'pid': 98.5,
#       'q_e_i': 3106,
#       'q_len': 4000,
#       'q_s_i': 1744,
#       'qcov': '34.1',
#       's_e_i': 1353,
#       's_s_i': 1}]},
#    {'Bac12248': [{'aln_len': 395,
#       'identities': 395,
#       'pid': 100.0,
#       'q_e_i': 395,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '9.88',
#       's_e_i': 2923,
#       's_s_i': 2529}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 634,
#       'q_len': 4000,
#       'q_s_i': 519,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_345': [{'DstMeta2': [{'aln_len': 84,
#       'identities': 79,
#       'pid': 95.2,
#       'q_e_i': 84,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '2.1',
#       's_e_i': 1568,
#       's_s_i': 1485}]},
#    {'Bac12248': [{'aln_len': 2930,
#       'identities': 2927,
#       'pid': 99.9,
#       'q_e_i': 3320,
#       'q_len': 4000,
#       'q_s_i': 391,
#       'qcov': '73.2',
#       's_e_i': 2931,
#       's_s_i': 1}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 3621,
#       'q_len': 4000,
#       'q_s_i': 3506,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_383': [{'NosSpe42': [{'aln_len': 75,
#       'identities': 59,
#       'pid': 78.9,
#       'q_e_i': 2679,
#       'q_len': 4000,
#       'q_s_i': 2605,
#       'qcov': '1.88',
#       's_e_i': 1673,
#       's_s_i': 1599}]},
#    {'Bac12248': [{'aln_len': 2063,
#       'identities': 2063,
#       'pid': 100.0,
#       'q_e_i': 2063,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '51.6',
#       's_e_i': 2923,
#       's_s_i': 861}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 2297,
#       'q_len': 4000,
#       'q_s_i': 2182,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_463': [{'LetYel14': [{'aln_len': 76,
#       'identities': 70,
#       'pid': 93.4,
#       'q_e_i': 2892,
#       'q_len': 4000,
#       'q_s_i': 2817,
#       'qcov': '1.9',
#       's_e_i': 1645,
#       's_s_i': 1570}]},
#    {'Bac12248': [{'aln_len': 978,
#       'identities': 978,
#       'pid': 100.0,
#       'q_e_i': 978,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '24.4',
#       's_e_i': 2923,
#       's_s_i': 1946}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 1286,
#       'q_len': 4000,
#       'q_s_i': 1171,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_465': [{'NosSpe42': [{'aln_len': 84,
#       'identities': 70,
#       'pid': 84.5,
#       'q_e_i': 2437,
#       'q_len': 4000,
#       'q_s_i': 2354,
#       'qcov': '2.1',
#       's_e_i': 1680,
#       's_s_i': 1599}]},
#    {'CloTet37': [{'aln_len': 158,
#       'identities': 123,
#       'pid': 78.4,
#       'q_e_i': 3217,
#       'q_len': 4000,
#       'q_s_i': 3060,
#       'qcov': '3.95',
#       's_e_i': 281,
#       's_s_i': 113}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 1608,
#       'q_len': 4000,
#       'q_s_i': 1493,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}]},
#  'Ot4b.31_nt': {'Frag_1078': [{'NosSpe42': [{'aln_len': 56,
#       'identities': 46,
#       'pid': 83.1,
#       'q_e_i': 3602,
#       'q_len': 4000,
#       'q_s_i': 3547,
#       'qcov': '1.4',
#       's_e_i': 1661,
#       's_s_i': 1607}]},
#    {'CanPhot8': [{'aln_len': 57,
#       'identities': 47,
#       'pid': 84.2,
#       'q_e_i': 3973,
#       'q_len': 4000,
#       'q_s_i': 3917,
#       'qcov': '1.43',
#       's_e_i': 59,
#       's_s_i': 3}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 117,
#       'identities': 113,
#       'pid': 96.6,
#       'q_e_i': 1495,
#       'q_len': 4000,
#       'q_s_i': 1379,
#       'qcov': '2.93',
#       's_e_i': 118,
#       's_s_i': 1}]}]},
#  'Ot4b.49_nt': {'Frag_1098': [{'Unc65040': [{'aln_len': 244,
#       'identities': 222,
#       'pid': 91.0,
#       'q_e_i': 4000,
#       'q_len': 4000,
#       'q_s_i': 3757,
#       'qcov': '6.1',
#       's_e_i': 244,
#       's_s_i': 1}]},
#    {'Bac12248': [{'aln_len': 1979,
#       'identities': 1979,
#       'pid': 100.0,
#       'q_e_i': 1979,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '49.5',
#       's_e_i': 2923,
#       's_s_i': 945}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 2284,
#       'q_len': 4000,
#       'q_s_i': 2169,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_1125': [{'EncFa169': [{'aln_len': 183,
#       'identities': 180,
#       'pid': 98.4,
#       'q_e_i': 183,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '4.58',
#       's_e_i': 1541,
#       's_s_i': 1358}]},
#    {'Bac12248': [{'aln_len': 2931,
#       'identities': 2931,
#       'pid': 100.0,
#       'q_e_i': 3435,
#       'q_len': 4000,
#       'q_s_i': 505,
#       'qcov': '73.3',
#       's_e_i': 2931,
#       's_s_i': 1}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 3666,
#       'q_len': 4000,
#       'q_s_i': 3551,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_1126': [{'LsnSph30': [{'aln_len': 1363,
#       'identities': 1342,
#       'pid': 98.5,
#       'q_e_i': 2538,
#       'q_len': 4000,
#       'q_s_i': 1176,
#       'qcov': '34.1',
#       's_e_i': 1353,
#       's_s_i': 1}]},
#    {'Bac12248': [{'aln_len': 940,
#       'identities': 939,
#       'pid': 99.9,
#       'q_e_i': 4000,
#       'q_len': 4000,
#       'q_s_i': 3061,
#       'qcov': '23.5',
#       's_e_i': 940,
#       's_s_i': 1}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 58,
#       'identities': 58,
#       'pid': 100.0,
#       'q_e_i': 58,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '1.45',
#       's_e_i': 108,
#       's_s_i': 51}]}],
#   'Frag_1159': [{'NosSpe42': [{'aln_len': 83,
#       'identities': 67,
#       'pid': 81.0,
#       'q_e_i': 1597,
#       'q_len': 4000,
#       'q_s_i': 1515,
#       'qcov': '2.08',
#       's_e_i': 1673,
#       's_s_i': 1591}]},
#    {'Bac12248': [{'aln_len': 1325,
#       'identities': 1325,
#       'pid': 100.0,
#       'q_e_i': 1325,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '33.1',
#       's_e_i': 2923,
#       's_s_i': 1599}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 116,
#       'identities': 116,
#       'pid': 100.0,
#       'q_e_i': 1512,
#       'q_len': 4000,
#       'q_s_i': 1397,
#       'qcov': '2.9',
#       's_e_i': 116,
#       's_s_i': 1}]}],
#   'Frag_812': [{'MedSativ': [{'aln_len': 93,
#       'identities': 79,
#       'pid': 85.7,
#       'q_e_i': 3798,
#       'q_len': 4000,
#       'q_s_i': 3706,
#       'qcov': '2.33',
#       's_e_i': 1658,
#       's_s_i': 1562}]},
#    {'CloTet37': [{'aln_len': 158,
#       'identities': 123,
#       'pid': 78.4,
#       'q_e_i': 3784,
#       'q_len': 4000,
#       'q_s_i': 3627,
#       'qcov': '3.95',
#       's_e_i': 281,
#       's_s_i': 113}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 2175,
#       'q_len': 4000,
#       'q_s_i': 2060,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_814': [{'NosSpe42': [{'aln_len': 84,
#       'identities': 70,
#       'pid': 84.5,
#       'q_e_i': 2682,
#       'q_len': 4000,
#       'q_s_i': 2599,
#       'qcov': '2.1',
#       's_e_i': 1680,
#       's_s_i': 1599}]},
#    {'Bac12248': [{'aln_len': 1545,
#       'identities': 1545,
#       'pid': 100.0,
#       'q_e_i': 1545,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '38.6',
#       's_e_i': 2923,
#       's_s_i': 1379}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 1853,
#       'q_len': 4000,
#       'q_s_i': 1738,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_894': [{'NosSpe42': [{'aln_len': 75,
#       'identities': 59,
#       'pid': 78.9,
#       'q_e_i': 3271,
#       'q_len': 4000,
#       'q_s_i': 3197,
#       'qcov': '1.88',
#       's_e_i': 1673,
#       's_s_i': 1599}]},
#    {'Bac12248': [{'aln_len': 2655,
#       'identities': 2652,
#       'pid': 99.9,
#       'q_e_i': 2655,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '66.4',
#       's_e_i': 2923,
#       's_s_i': 269}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 2889,
#       'q_len': 4000,
#       'q_s_i': 2774,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}]},
#  'RB-21': {'Frag_1276': [{'LetYel14': [{'aln_len': 77,
#       'identities': 70,
#       'pid': 92.2,
#       'q_e_i': 671,
#       'q_len': 4000,
#       'q_s_i': 595,
#       'qcov': '1.93',
#       's_e_i': 1648,
#       's_s_i': 1572}]},
#    {'CloTet37': [{'aln_len': 162,
#       'identities': 127,
#       'pid': 78.7,
#       'q_e_i': 672,
#       'q_len': 4000,
#       'q_s_i': 511,
#       'qcov': '4.05',
#       's_e_i': 282,
#       's_s_i': 111}]},
#    {'AAKN02015069.1/34289-34169': [{'aln_len': 44,
#       'identities': 37,
#       'pid': 84.1,
#       'q_e_i': 291,
#       'q_len': 4000,
#       'q_s_i': 248,
#       'qcov': '1.1',
#       's_e_i': 109,
#       's_s_i': 66}]}],
#   'Frag_1277': [{'NosSpe42': [{'aln_len': 83,
#       'identities': 67,
#       'pid': 81.0,
#       'q_e_i': 3028,
#       'q_len': 4000,
#       'q_s_i': 2946,
#       'qcov': '2.08',
#       's_e_i': 1673,
#       's_s_i': 1591}]},
#    {'Bac12248': [{'aln_len': 2756,
#       'identities': 2753,
#       'pid': 99.9,
#       'q_e_i': 2756,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '68.9',
#       's_e_i': 2923,
#       's_s_i': 168}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 116,
#       'identities': 116,
#       'pid': 100.0,
#       'q_e_i': 2943,
#       'q_len': 4000,
#       'q_s_i': 2828,
#       'qcov': '2.9',
#       's_e_i': 116,
#       's_s_i': 1}]}],
#   'Frag_1315': [{'Unc10009': [{'aln_len': 252,
#       'identities': 250,
#       'pid': 99.6,
#       'q_e_i': 252,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '6.3',
#       's_e_i': 1556,
#       's_s_i': 1306}]},
#    {'Bac12248': [{'aln_len': 2931,
#       'identities': 2928,
#       'pid': 99.9,
#       'q_e_i': 3694,
#       'q_len': 4000,
#       'q_s_i': 764,
#       'qcov': '73.3',
#       's_e_i': 2931,
#       's_s_i': 1}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 3918,
#       'q_len': 4000,
#       'q_s_i': 3803,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_1316': [{'LsnSph30': [{'aln_len': 1363,
#       'identities': 1338,
#       'pid': 98.2,
#       'q_e_i': 3842,
#       'q_len': 4000,
#       'q_s_i': 2480,
#       'qcov': '34.1',
#       's_e_i': 1353,
#       's_s_i': 1}]},
#    {'Bac12248': [{'aln_len': 1131,
#       'identities': 1131,
#       'pid': 100.0,
#       'q_e_i': 1131,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '28.3',
#       's_e_i': 2923,
#       's_s_i': 1793}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 1369,
#       'q_len': 4000,
#       'q_s_i': 1254,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_1345': [{'Unc00n3n': [{'aln_len': 994,
#       'identities': 944,
#       'pid': 95.0,
#       'q_e_i': 3987,
#       'q_len': 4000,
#       'q_s_i': 2994,
#       'qcov': '24.9',
#       's_e_i': 995,
#       's_s_i': 1}]},
#    {'Bac12248': [{'aln_len': 1168,
#       'identities': 1166,
#       'pid': 99.9,
#       'q_e_i': 1168,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '29.2',
#       's_e_i': 2923,
#       's_s_i': 1756}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 1401,
#       'q_len': 4000,
#       'q_s_i': 1286,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_228': [{'Unc036po': [{'aln_len': 180,
#       'identities': 180,
#       'pid': 100.0,
#       'q_e_i': 180,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '4.5',
#       's_e_i': 1477,
#       's_s_i': 1298}]},
#    {'Bac12248': [{'aln_len': 2931,
#       'identities': 2931,
#       'pid': 100.0,
#       'q_e_i': 3452,
#       'q_len': 4000,
#       'q_s_i': 522,
#       'qcov': '73.3',
#       's_e_i': 2931,
#       's_s_i': 1}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 3679,
#       'q_len': 4000,
#       'q_s_i': 3564,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_229': [{'NosSpe42': [{'aln_len': 56,
#       'identities': 46,
#       'pid': 83.1,
#       'q_e_i': 158,
#       'q_len': 4000,
#       'q_s_i': 103,
#       'qcov': '1.4',
#       's_e_i': 1661,
#       's_s_i': 1607}]},
#    {'CanPhot8': [{'aln_len': 80,
#       'identities': 64,
#       'pid': 80.5,
#       'q_e_i': 470,
#       'q_len': 4000,
#       'q_s_i': 391,
#       'qcov': '2',
#       's_e_i': 82,
#       's_s_i': 2}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 71,
#       'identities': 71,
#       'pid': 100.0,
#       'q_e_i': 71,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '1.77',
#       's_e_i': 108,
#       's_s_i': 38}]}],
#   'Frag_3': [{'Unc00n3n': [{'aln_len': 691,
#       'identities': 654,
#       'pid': 94.7,
#       'q_e_i': 3998,
#       'q_len': 4000,
#       'q_s_i': 3308,
#       'qcov': '17.3',
#       's_e_i': 693,
#       's_s_i': 1}]},
#    {'Bac12248': [{'aln_len': 1482,
#       'identities': 1480,
#       'pid': 99.9,
#       'q_e_i': 1482,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '37',
#       's_e_i': 2923,
#       's_s_i': 1442}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 1715,
#       'q_len': 4000,
#       'q_s_i': 1600,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_314': [{'NosSpe42': [{'aln_len': 86,
#       'identities': 71,
#       'pid': 83.7,
#       'q_e_i': 3583,
#       'q_len': 4000,
#       'q_s_i': 3498,
#       'qcov': '2.15',
#       's_e_i': 1682,
#       's_s_i': 1599}]},
#    {'Bac12248': [{'aln_len': 2439,
#       'identities': 2439,
#       'pid': 100.0,
#       'q_e_i': 2439,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '61',
#       's_e_i': 2923,
#       's_s_i': 485}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 2748,
#       'q_len': 4000,
#       'q_s_i': 2633,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_316': [{'NosSpe42': [{'aln_len': 74,
#       'identities': 58,
#       'pid': 78.7,
#       'q_e_i': 3151,
#       'q_len': 4000,
#       'q_s_i': 3078,
#       'qcov': '1.85',
#       's_e_i': 1673,
#       's_s_i': 1600}]},
#    {'PseA1731': [{'aln_len': 77,
#       'identities': 69,
#       'pid': 90.9,
#       'q_e_i': 3894,
#       'q_len': 4000,
#       'q_s_i': 3818,
#       'qcov': '1.93',
#       's_e_i': 77,
#       's_s_i': 1}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 3067,
#       'q_len': 4000,
#       'q_s_i': 2952,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_69': [{'NosSpe42': [{'aln_len': 75,
#       'identities': 59,
#       'pid': 78.9,
#       'q_e_i': 3567,
#       'q_len': 4000,
#       'q_s_i': 3493,
#       'qcov': '1.88',
#       's_e_i': 1673,
#       's_s_i': 1599}]},
#    {'Bac12248': [{'aln_len': 897,
#       'identities': 897,
#       'pid': 100.0,
#       'q_e_i': 897,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '22.4',
#       's_e_i': 2923,
#       's_s_i': 2027}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 113,
#       'pid': 97.5,
#       'q_e_i': 1204,
#       'q_len': 4000,
#       'q_s_i': 1089,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}]},
#  'Silvestris': {'Frag_1066': [{'Unc036po': [{'aln_len': 464,
#       'identities': 462,
#       'pid': 99.6,
#       'q_e_i': 464,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '11.6',
#       's_e_i': 1477,
#       's_s_i': 1014}]},
#    {'SobSil34': [{'aln_len': 2926,
#       'identities': 2914,
#       'pid': 99.6,
#       'q_e_i': 3662,
#       'q_len': 4000,
#       'q_s_i': 737,
#       'qcov': '73.2',
#       's_e_i': 2925,
#       's_s_i': 1}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 3899,
#       'q_len': 4000,
#       'q_s_i': 3784,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_1067': [{'LsnSph30': [{'aln_len': 1364,
#       'identities': 1298,
#       'pid': 95.2,
#       'q_e_i': 2764,
#       'q_len': 4000,
#       'q_s_i': 1401,
#       'qcov': '34.1',
#       's_e_i': 1353,
#       's_s_i': 1}]},
#    {'SobSil34': [{'aln_len': 751,
#       'identities': 748,
#       'pid': 99.7,
#       'q_e_i': 4000,
#       'q_len': 4000,
#       'q_s_i': 3250,
#       'qcov': '18.8',
#       's_e_i': 751,
#       's_s_i': 1}]},
#    {'CP000817.1/649536-649653': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 98.3,
#       'q_e_i': 299,
#       'q_len': 4000,
#       'q_s_i': 184,
#       'qcov': '2.9',
#       's_e_i': 118,
#       's_s_i': 1}]}],
#   'Frag_1093': [{'Unc00r8y': [{'aln_len': 1405,
#       'identities': 1306,
#       'pid': 93.0,
#       'q_e_i': 2263,
#       'q_len': 4000,
#       'q_s_i': 859,
#       'qcov': '35.1',
#       's_e_i': 1395,
#       's_s_i': 1}]},
#    {'SobSil34': [{'aln_len': 1111,
#       'identities': 1107,
#       'pid': 99.7,
#       'q_e_i': 4000,
#       'q_len': 4000,
#       'q_s_i': 2890,
#       'qcov': '27.8',
#       's_e_i': 1111,
#       's_s_i': 1}]},
#    {'AAKN02015069.1/34289-34169': [{'aln_len': 44,
#       'identities': 37,
#       'pid': 84.1,
#       'q_e_i': 2664,
#       'q_len': 4000,
#       'q_s_i': 2621,
#       'qcov': '1.1',
#       's_e_i': 109,
#       's_s_i': 66}]}],
#   'Frag_1094': [{'NosSpe42': [{'aln_len': 78,
#       'identities': 63,
#       'pid': 81.2,
#       'q_e_i': 2574,
#       'q_len': 4000,
#       'q_s_i': 2497,
#       'qcov': '1.95',
#       's_e_i': 1673,
#       's_s_i': 1595}]},
#    {'SobSil34': [{'aln_len': 2207,
#       'identities': 2198,
#       'pid': 99.6,
#       'q_e_i': 2207,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '55.2',
#       's_e_i': 2917,
#       's_s_i': 712}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 116,
#       'identities': 116,
#       'pid': 100.0,
#       'q_e_i': 2491,
#       'q_len': 4000,
#       'q_s_i': 2376,
#       'qcov': '2.9',
#       's_e_i': 116,
#       's_s_i': 1}]}],
#   'Frag_46': [{'LetYel14': [{'aln_len': 89,
#       'identities': 80,
#       'pid': 89.9,
#       'q_e_i': 1690,
#       'q_len': 4000,
#       'q_s_i': 1602,
#       'qcov': '2.23',
#       's_e_i': 1648,
#       's_s_i': 1563}]},
#    {'SobSil34': [{'aln_len': 319,
#       'identities': 317,
#       'pid': 99.4,
#       'q_e_i': 319,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '7.98',
#       's_e_i': 2918,
#       's_s_i': 2600}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 116,
#       'identities': 114,
#       'pid': 99.1,
#       'q_e_i': 517,
#       'q_len': 4000,
#       'q_s_i': 402,
#       'qcov': '2.9',
#       's_e_i': 116,
#       's_s_i': 1}]}],
#   'Frag_729': [{'LetYel14': [{'aln_len': 96,
#       'identities': 77,
#       'pid': 80.6,
#       'q_e_i': 427,
#       'q_len': 4000,
#       'q_s_i': 332,
#       'qcov': '2.4',
#       's_e_i': 1664,
#       's_s_i': 1567}]},
#    {'CloTet37': [{'aln_len': 166,
#       'identities': 131,
#       'pid': 79.2,
#       'q_e_i': 972,
#       'q_len': 4000,
#       'q_s_i': 807,
#       'qcov': '4.15',
#       's_e_i': 282,
#       's_s_i': 116}]},
#    {'AAKN02015069.1/34289-34169': [{'aln_len': 44,
#       'identities': 37,
#       'pid': 84.1,
#       'q_e_i': 196,
#       'q_len': 4000,
#       'q_s_i': 153,
#       'qcov': '1.1',
#       's_e_i': 109,
#       's_s_i': 66}]}],
#   'Frag_730': [{'NosSpe42': [{'aln_len': 78,
#       'identities': 63,
#       'pid': 81.2,
#       'q_e_i': 3079,
#       'q_len': 4000,
#       'q_s_i': 3002,
#       'qcov': '1.95',
#       's_e_i': 1673,
#       's_s_i': 1595}]},
#    {'SobSil34': [{'aln_len': 2785,
#       'identities': 2773,
#       'pid': 99.6,
#       'q_e_i': 2785,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '69.6',
#       's_e_i': 2917,
#       's_s_i': 134}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 116,
#       'identities': 116,
#       'pid': 100.0,
#       'q_e_i': 2996,
#       'q_len': 4000,
#       'q_s_i': 2881,
#       'qcov': '2.9',
#       's_e_i': 116,
#       's_s_i': 1}]}],
#   'Frag_927': [{'Unc036po': [{'aln_len': 230,
#       'identities': 230,
#       'pid': 100.0,
#       'q_e_i': 230,
#       'q_len': 4000,
#       'q_s_i': 1,
#       'qcov': '5.75',
#       's_e_i': 1477,
#       's_s_i': 1248}]},
#    {'SobSil34': [{'aln_len': 2926,
#       'identities': 2917,
#       'pid': 99.7,
#       'q_e_i': 3513,
#       'q_len': 4000,
#       'q_s_i': 588,
#       'qcov': '73.2',
#       's_e_i': 2925,
#       's_s_i': 1}]},
#    {'AAXV01000026.1/49382-49267': [{'aln_len': 116,
#       'identities': 116,
#       'pid': 100.0,
#       'q_e_i': 3716,
#       'q_len': 4000,
#       'q_s_i': 3601,
#       'qcov': '2.9',
#       's_e_i': 116,
#       's_s_i': 1}]}]}}

# %%
#listTest = sorted(genos_results_subunits_dict['2362_nt'].keys())
#fragNumbersTest = [ fragTemp.split("_")[1] for fragTemp in listTest]

# %%
#fragNumbersTest

# %%
#genos_results_subunits_dict['2362_nt']['Frag_1099']

# %% [markdown]
# # Making dataframe of fragments of all genomes

# %%
# Making dataframe of fragments of all genomes
#genos_results_subunits_dict

# %%
for key in genos_results_subunits_dict:
    
    print key
    
    for key2 in genos_results_subunits_dict[key]:
        print key2
        listKey2 = genos_results_subunits_dict[key][key2]
    
        listInsideTempAln_Len = []
        for dictTemp in listKey2:
            for insideKey in dictTemp:
                listInsideTempAln_Len.append(dictTemp[insideKey][0]['aln_len'])
            
        print listInsideTempAln_Len
        
        if(listInsideTempAln_Len[0]>=1300):
            print "Subunit accepted"
        if(listInsideTempAln_Len[1]>=2460):
            print "Subunit accepted"
        if(listInsideTempAln_Len[2]>=100):
            print "Subunit accepted"
    
    print "\n"
# Out:
# CBAM5_nt
# Frag_740
# [165, 1515, 116]
# Subunit accepted
# Frag_486
# [29, 57, 116]
# Subunit accepted
# Frag_583
# [172, 162, 62]
# Frag_733
# [74, 76, 116]
# Subunit accepted
# Frag_732
# [69, 69, 44]
# Frag_523
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_648
# [84, 101, 116]
# Subunit accepted
#
#
# 2362_nt
# Frag_434
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_504
# [75, 779, 116]
# Subunit accepted
# Frag_566
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_394
# [896, 2931, 116]
# Subunit accepted
# Subunit accepted
# Frag_550
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_453
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_393
# [93, 158, 116]
# Subunit accepted
# Frag_591
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_541
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_535
# [1363, 402, 44]
# Subunit accepted
# Frag_536
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
#
#
# C3-41_nt
# Frag_106
# [1362, 2929, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_8
# [346, 2931, 116]
# Subunit accepted
# Subunit accepted
# Frag_579
# [93, 158, 116]
# Subunit accepted
# Frag_16
# [1362, 2930, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_616
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_32
# [498, 2930, 116]
# Subunit accepted
# Subunit accepted
# Frag_3
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_51
# [75, 2533, 116]
# Subunit accepted
# Subunit accepted
# Frag_615
# [75, 449, 116]
# Subunit accepted
# Frag_107
# [77, 288, 116]
# Subunit accepted
#
#
# Ot4b.25_nt
# Frag_121
# [1363, 2930, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_232
# [76, 978, 116]
# Subunit accepted
# Frag_34
# [173, 2931, 116]
# Subunit accepted
# Subunit accepted
# Frag_233
# [84, 158, 116]
# Subunit accepted
# Frag_157
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_173
# [84, 2930, 116]
# Subunit accepted
# Subunit accepted
# Frag_90
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_75
# [78, 2930, 116]
# Subunit accepted
# Subunit accepted
# Frag_192
# [75, 2063, 116]
# Subunit accepted
# Frag_59
# [82, 2290, 116]
# Subunit accepted
# Frag_76
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_89
# [1363, 2930, 115]
# Subunit accepted
# Subunit accepted
# Subunit accepted
#
#
# Silvestris
# Frag_435
# [1405, 2926, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_365
# [89, 2926, 116]
# Subunit accepted
# Subunit accepted
# Frag_493
# [79, 896, 116]
# Subunit accepted
# Frag_471
# [1405, 2926, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_547
# [1405, 2926, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_23
# [644, 2926, 116]
# Subunit accepted
# Subunit accepted
# Frag_534
# [1364, 2926, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_533
# [1405, 2926, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_464
# [1405, 2926, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_524
# [1405, 2926, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_525
# [1405, 2926, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
#
#
# B1-CDA_nt
# Frag_1
# [83, 84, 95]
#
#
# Ot4b.31_nt
#
#
# RB-21
# Frag_115
# [56, 80, 71]
# Frag_114
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_639
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_35
# [75, 897, 116]
# Subunit accepted
# Frag_2
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_667
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_658
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_95
# [849, 2931, 116]
# Subunit accepted
# Subunit accepted
# Frag_672
# [1289, 2930, 116]
# Subunit accepted
# Subunit accepted
# Frag_1
# [1363, 2930, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_158
# [82, 155, 116]
# Subunit accepted
# Frag_157
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_77
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_673
# [994, 2557, 116]
# Subunit accepted
# Subunit accepted
#
#
# Ot4b.49_nt
# Frag_549
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_447
# [56, 2931, 116]
# Subunit accepted
# Subunit accepted
# Frag_482
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_550
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_580
# [83, 1325, 116]
# Subunit accepted
# Frag_563
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_466
# [1015, 2931, 116]
# Subunit accepted
# Subunit accepted
# Frag_518
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_407
# [82, 1945, 116]
# Subunit accepted
# Frag_406
# [93, 158, 116]
# Subunit accepted
#
#
# III37_nt
# Frag_38
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_110
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_105
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_106
# [892, 2931, 116]
# Subunit accepted
# Subunit accepted
# Frag_608
# [93, 158, 116]
# Subunit accepted
# Frag_119
# [1363, 2674, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_3
# [523, 2931, 116]
# Subunit accepted
# Subunit accepted
# Frag_22
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_609
# [76, 733, 116]
# Subunit accepted
# Frag_74
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_135
# [1363, 2931, 116]
# Subunit accepted
# Subunit accepted
# Subunit accepted
# Frag_136
# [77, 573, 116]
# Subunit accepted

# %%
## Function 25
def parsing_data_as_df_for_each_geno(genos_results_subunits_dict):
    
    # importing pandas
    import pandas as pd
    from pandas import DataFrame

    # Dict genos
    
    dict_genos_lists_for_df = {}
    
    frag_temp_by_geno = []
    aln_by_frag_temp_by_geno = []
    
    for key in genos_results_subunits_dict:
        # Geno key
        print key
    
        for key2 in genos_results_subunits_dict[key]:
            
            # Frag key
            #print key2
            listKey2 = genos_results_subunits_dict[key][key2]
            
            listInsideTempAln_Len = []
            for dictTemp in listKey2:
                for insideKey in dictTemp:
                    listInsideTempAln_Len.append(dictTemp[insideKey][0]['aln_len'])
                
            # List of aln 
            if(listInsideTempAln_Len[0]>=1300 and listInsideTempAln_Len[1]>=2460 and listInsideTempAln_Len[2]>=100):
                #print "Operons accepted"
                print key2
                print listInsideTempAln_Len
                # filling frag list
                frag_temp_by_geno.append(key2)
                aln_by_frag_temp_by_geno.append(listInsideTempAln_Len)
                
        print "\n"       
        
        dfTemp = making_df_by_geno(key,frag_temp_by_geno,aln_by_frag_temp_by_geno)
        dict_genos_lists_for_df[key]= dfTemp

    return(dict_genos_lists_for_df)

# %%
# parsing as dataframe

r1test = parsing_data_as_df_for_each_geno(genos_results_subunits_dict)
# Out:
# CBAM5_nt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-6562dda83b0a> in <module>()
#       1 # parsing as dataframe
#       2
# ----> 3 r1test = parsing_data_as_df_for_each_geno(genos_results_subunits_dict)
#
# <ipython-input-46-dbd9b780f0e1> in parsing_data_as_df_for_each_geno(genos_results_subunits_dict)
#      39         print "\n"
#      40
# ---> 41         dfTemp = making_df_by_geno(key,frag_temp_by_geno,aln_by_frag_temp_by_geno)
#      42         dict_genos_lists_for_df[key]= dfTemp
#      43
#
# NameError: global name 'making_df_by_geno' is not defined

# %%
r1test.keys()
# Out:
# ['CBAM5_nt',
#  '2362_nt',
#  'C3-41_nt',
#  'Ot4b.25_nt',
#  'Silvestris',
#  'III37_nt',
#  'Ot4b.31_nt',
#  'RB-21',
#  'Ot4b.49_nt',
#  'B1-CDA_nt']

# %%
def making_df_by_geno(genoName,frag_temp_by_geno,aln_by_frag_temp_by_geno):
    
      # importing pandas
    import pandas as pd
    from pandas import DataFrame
    
    len1 = len(frag_temp_by_geno)
    len2 = len(aln_by_frag_temp_by_geno)
    
    if(len1 != len2):
        
        print "There is a problem"
    else:
        dColumns={
            '1_GenoName' : genoName,
            '2_FragNumbers' : frag_temp_by_geno,
            '3_Aln_sizes': aln_by_frag_temp_by_geno
        }    
    
    df = pd.DataFrame(dColumns)
    
    return(df)

# %%
os.getcwd()
# Out:
# '/Users/CamilaMV/Desktop'

# %%
# Using complete_list_dfs to get list of dfs
all_dfs_with_last_properties = complete_list_dfs(r1test)

os.getcwd()

# run function
multiple_dfs(all_dfs_with_last_properties, '10_Geno_Jeny', '10_Proca_4k-400.xlsx', 1)

# %%
#listInsideTempAln_Len = []
#for dictTemp in listKey2:
    
#    for insideKey in dictTemp:
        
#        listInsideTempAln_Len.append(dictTemp[insideKey][0]['aln_len'])

# %%
len1 = len(operonNumberList)
    len2 = len(list_operons_f2)
    len3 = len(final_posiFrag_f2)
    
    if(len1 != len2 and len1 == len3):
        
        dColumns={

            '1_OperoNumbers' : operonNumberList,
            '2_Posi_Definitive_in_Image': final_posiFrag_f2

        }
        
        df = pd.DataFrame(dColumns)
        
        additionalDisposition = pd.DataFrame({'3_DispositionOperons' : list_operons_f2})
        newTemp1 = pd.concat([df,additionalDisposition], axis=1)
        
        # Adding other things
        additionalTemp = pd.DataFrame({'4_Operon_names' : count_operon_names,
                                           '5_NumberofSubunitsbyOperon' : count_operon_list})
        newTemp2 = pd.concat([newTemp1,additionalTemp], axis=1)

        #adding geno name
        additionalName = pd.DataFrame({'6_GenoName' : genoName},index=[0])
        newTemp3 = pd.concat([newTemp2,additionalName], axis=1) 
        
        dataFrameToReturn = newTemp3

    else:
        dColumns={

            '1_OperoNumbers' : operonNumberList,
            '2_Posi_Definitive_in_Image': final_posiFrag_f2,
            '3_DispositionOperons': list_operons_f2
        }

        df = pd.DataFrame(dColumns)
        
        # Adding other things
        additionalTemp = pd.DataFrame({'4_Operon_names' : count_operon_names,
                                           '5_NumberofSubunitsbyOperon' : count_operon_list})
        newTemp1 = pd.concat([df,additionalTemp], axis=1)

        #adding geno name
        additionalName = pd.DataFrame({'6_GenoID' : genoName},index=[0])
        newTemp2 = pd.concat([newTemp1,additionalName], axis=1)
        
        dataFrameToReturn = newTemp2

# %%
if(listInsideTempAln_Len[0]>=1300):
    print "Subunit accepted"
if(listInsideTempAln_Len[1]>=2460):
    print "Subunit accepted"
if(listInsideTempAln_Len[2]>=100):
    print "Subunit accepted"
# Out:
# Subunit accepted

# %%
def complete_list_dfs(dict_test_list_dfs):
    
    all_dfs = []
    for key in dict_test_list_dfs:
        
        dfTemp = dict_test_list_dfs[key]
        all_dfs.append(dfTemp)
        
    return all_dfs

# %% [markdown]
# # It does not work as function ??, I have to know why ?

# %%
# It does not work as function ??, I have to know why ?

"""
def processing_subunit_blast_files_for_genos(genosNamesFasta,genosNamesFinalBlast,nameGenos,folder16s,folder23s,folder5s,mainPath2):
    
    #path16s, path23s and path5s are constant
    genos_results_subunits_dict = {}
    
    # Processing tabular results
    for genoFasta, genoblast, gname in itertools.izip(genosNamesFasta,genosNamesFinalBlast,nameGenos):
        
        # Query lengths temporal
        pathTemp = mainPath2 + genoFasta
        query_files = [pathTemp]
        query_lengths = {rec.name:len(rec.seq) for q_file in query_files for rec in SeqIO.parse(q_file, 'fasta')}
        
        # Processing blast results
        p16s = folder16s+genoblast
        p23s = folder23s+genoblast
        p5s = folder5s+genoblast
        
        # Using function parse_tabular_blast_results, NOT MINE
        results_geno_temp_16s = parse_tabular_blast_results(p16s)
        results_geno_temp_23s = parse_tabular_blast_results(p23s)
        results_geno_temp_5s = parse_tabular_blast_results(p5s)
    
        # Making intersection for each geno
        intersection_16_23s_geno_temp = set(results_geno_temp_16s.keys()).intersection(results_geno_temp_23s.keys())
        intersection_16_23_5s_geno_temp = intersection_16_23s_geno_temp.intersection(results_geno_temp_5s.keys())
    
        # Putting results for each geno as value of dictionary
        dict_frag_subunits = {}
        for keyFrag in intersection_16_23_5s_geno_temp:
        
            listTemp = [results_geno_temp_16s[keyFrag],results_geno_temp_23s[keyFrag],results_geno_temp_5s[keyFrag]]
        
            dict_frag_subunits[keyFrag] = listTemp
        
        # Putting final results in big dictionary
        genos_results_subunits_dict[gname] = dict_frag_subunits 
    
    return genos_results_subunits_dict
    
"""

# %%
#testBigDict = processing_subunit_blast_files_for_genos(genosNamesFasta,genosNamesFinalBlast,nameGenos,folder16s,folder23s,folder5s,mainPath2)

# %%
#for root, dirs, files in os.walk("/Users/CamilaMV/Desktop/", topdown=False):
#    for name in files:
#        print(os.path.join(root, name))
#    for name in dirs:
#        print(os.path.join(root, name))
